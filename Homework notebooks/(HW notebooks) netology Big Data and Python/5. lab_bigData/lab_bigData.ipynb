# %% [markdown]
# # 1. Загрузка данных

# %%
import pandas as pd
# df = pd.read_csv('https://raw.githubusercontent.com/chendaniely/pandas_for_everyone/master/data/wine.csv')
df = pd.read_csv('wine.csv')

# %%
df.head()
# Out:
#    Cultivar  Alcohol  ...  OD280/OD315 of diluted wines  Proline
# 0         1    14.23  ...                          3.92                 1065
# 1         1    13.20  ...                          3.40                 1050
# 2         1    13.16  ...                          3.17                 1185
# 3         1    14.37  ...                          3.45                 1480
# 4         1    13.24  ...                          2.93                  735
#
# [5 rows x 14 columns]

# %% [markdown]
# # 2. Для каждого атрибута вывести максимальное, минимальное и среднее значение

# %%
df.describe()
# Out:
#          Cultivar  ...  Proline
# count  178.000000  ...           178.000000
# mean     1.938202  ...           746.893258
# std      0.775035  ...           314.907474
# min      1.000000  ...           278.000000
# 25%      1.000000  ...           500.500000
# 50%      2.000000  ...           673.500000
# 75%      3.000000  ...           985.000000
# max      3.000000  ...          1680.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# # 3. Вывести матрицу корреляций между признаками

# %%
df.corr()
# Out:
#                               Cultivar  ...  Proline
# Cultivar                      1.000000  ...            -0.633717
# Alcohol                      -0.328222  ...             0.643720
# Malic acid                    0.437776  ...            -0.192011
# Ash                          -0.049643  ...             0.223626
# Alcalinity of ash             0.517859  ...            -0.440597
# Magnesium                    -0.209179  ...             0.393351
# Total phenols                -0.719163  ...             0.498115
# Flavanoids                   -0.847498  ...             0.494193
# Nonflavanoid phenols          0.489109  ...            -0.311385
# Proanthocyanins              -0.499130  ...             0.330417
# Color intensity               0.265668  ...             0.316100
# Hue                          -0.617369  ...             0.236183
# OD280/OD315 of diluted wines -0.788230  ...             0.312761
# Proline                      -0.633717  ...             1.000000
#
# ...

# %% [markdown]
# # 4. Для каждого признака построить гистограмму его значений

# %%
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %%
# Получим имена колонок
column_names = df.columns.values
column_names
# Out:
# array(['Cultivar', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash  ',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline            '],
#       dtype=object)

# %%
# будем рисовать сразу несколько графиков в одном выводе
# для этого воспользуемся функцией subplot из библиотеки matplotlib

COUNT_OF_PLOTS_HORIZONTAL = 4
COUNT_OF_PLOTS_VERTICAL = math.ceil(len(column_names) / COUNT_OF_PLOTS_HORIZONTAL)

# %%
plt.figure(figsize=(14,8))

for i, cn in enumerate(column_names):
  plt.subplot(COUNT_OF_PLOTS_VERTICAL, COUNT_OF_PLOTS_HORIZONTAL, i + 1)
  df[cn].hist()
  plt.title(cn)

# %%
# Или проще
df.hist()
plt.show()

# %% [markdown]
# # 5. Построить классификатор для вин (целевая переменная - Cultivar)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X, y = df[['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash  ',
       'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
       'Proanthocyanins', 'Color intensity', 'Hue',
       'OD280/OD315 of diluted wines', 'Proline            ']], df[['Cultivar']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
# ...

# %% [markdown]
# # 6. Оценить качество классификатора на отложенной (train_test_split) выборке

# %%
model.score(X_test, y_test)
# Out:
# 0.9722222222222222

# %%
pass
