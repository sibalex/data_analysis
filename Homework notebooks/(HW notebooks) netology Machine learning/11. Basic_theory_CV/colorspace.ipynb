# %% [markdown]
# # Цветовые пространства

# %% [markdown]
# ## Загрузка изображения из файла

# %%
import cv2

# %%
img = cv2.imread('./lena.png', cv2.IMREAD_COLOR)

# %%
plt.imshow(img[:100])

# %%
plt.imshow(img[50:400, 100:400])

# %%
print('type: ', type(img))
print('shape: ', img.shape)
# Out:
# type:  <class 'numpy.ndarray'>
# shape:  (512, 512, 3)

# %% [markdown]
# Самый первый пиксель:

# %%
img[0][0]
# Out:
# array([125, 137, 226], dtype=uint8)

# %% [markdown]
# ## Визуализация в matplotlib

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# Изображение выглядит странновато. Это потому, что красный, синий и зелёный стоят не в том порядке, который ожидает матплотлиб.

# %%
# изменяем порядок каналов для визуализации (b, g, r) -> (r, g, b)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
img2_1 = img[..., :: -1] # ... алиес для всех размерностей которые были до этого
# img2_1 = img[:, :, ::-1] # тоже самое первое измерение, второе измерение, на 3-ем перевернули 
#(::-1  - слайс от начала до конца с шагом -1)
plt.imshow(img2_1)

# %%
import numpy as np

# %% [markdown]
# Самый первый пиксель:

# %%
img[0][0]
# Out:
# array([125, 137, 226], dtype=uint8)

# %%
img2[0][0]
# Out:
# array([226, 137, 125], dtype=uint8)

# %% [markdown]
# Все красные пиксели:

# %%
img2[:, :, 0]
# Out:
# array([[125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        ...,
#        [ 60,  60,  58, ...,  84,  76,  79],
#        [ 57,  57,  62, ...,  79,  81,  81],
#        [ 57,  57,  62, ...,  79,  81,  81]], dtype=uint8)

# %%
img2[:, :, 1] = 0 # 1 - зеленые
img2[:, :, 2] = 0 # 2 - голубые

plt.imshow(img2)

# %% [markdown]
# ## Переходим в пространство цветов HSV

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
plt.figure(1, figsize = (16, 4))
plt.subplot(141)
plt.imshow(img2)
plt.subplot(142)
plt.imshow(img_hsv[...,0], cmap='gray')
plt.title('Hue')
plt.subplot(143)
plt.imshow(img_hsv[...,1], cmap='gray')
plt.title('Saturation')
plt.subplot(144)
plt.imshow(img_hsv[...,2], cmap='gray')
plt.title('Value');

# %% [markdown]
# #### Справка про numpy
# `matrix[..., 0]` -- в данном случае то же, что `matrix[:, :, 0]`: взять второй элемент из самых вложенных массивов.

# %%
img_hsv[..., 0]
# Out:
# array([[  4,   4,   1, ...,   7,   5,   2],
#        [  4,   4,   1, ...,   7,   5,   2],
#        [  4,   4,   1, ...,   7,   5,   2],
#        ...,
#        [161, 161, 166, ..., 177, 178, 176],
#        [163, 163, 166, ..., 178, 177, 178],
#        [163, 163, 166, ..., 178, 177, 178]], dtype=uint8)

# %%
img_hsv[:, :, 0]
# Out:
# array([[  4,   4,   1, ...,   7,   5,   2],
#        [  4,   4,   1, ...,   7,   5,   2],
#        [  4,   4,   1, ...,   7,   5,   2],
#        ...,
#        [161, 161, 166, ..., 177, 178, 176],
#        [163, 163, 166, ..., 178, 177, 178],
#        [163, 163, 166, ..., 178, 177, 178]], dtype=uint8)

# %%
# a = np.arange(8)
# ## print(a[:, :, ::-1]) строка, столбец, цвета от начала до конца с шагом -1
# print(a[5:])
# print(a[:5])
# print(a[:])
# print(a[::2])
# print(a[::-1])
# print(a[::-2])

# b = a.reshape(2, 2, 2)
# b[..., ::-1] # все до последнего
# b[..., ::-1, ::-1] # все до предпоследнего

# %% [markdown]
# ### Задания
#
# (можно по желанию и в зависимости от вашей скорости выполнять любые из них)
#
# * Сделайте то же самое, но для HLS (`cv2.COLOR_RGB2HLS`)
# * Так же загрузите и поэкспериментируйте с любым другим изображением
# * Уберите из матрицы изображения зелёную составляющую; визуализируйте результат
# * Поставьте в матрици изображения синюю составляющую на максимум; визуализируйте результат
# * Реализуйте один из алгоритмов перехода от RGB к друному формату
# * Если вы всё сделали и вам скучно, поизучайте [туториал opencv](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_core/py_basic_ops/py_basic_ops.html#basic-ops)

# %%
kitten = cv2.imread('kitten-report.jpg')

# %%
plt.imshow(kitten[..., ::-1]) # приводим к формату mpl

# %%
kitten[..., 1] = 0

# %%
plt.imshow(kitten[..., ::-1])

# %%
kitten2 = cv2.imread('kitten-report.jpg', cv2.IMREAD_COLOR)

# %%
plt.imshow(kitten2[..., ::-1])

# %%
kitten2[..., 0] = 0
kitten2[..., 1] = 0

plt.imshow(kitten2)

# %%
pass
